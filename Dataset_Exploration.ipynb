# %% [markdown]
# ## Artificial Intelligence Project Deliverable 1

# %% [markdown]
# ### Q1. As per your assigned groups for the semester, discover all possible open-source datasets that are relevant to your research area.

# %% [markdown]
# 1. [Plant Village CC BY-NC-SA 4.0](https://www.kaggle.com/datasets/abdallahalidev/plantvillage-dataset)
# 2. [Plant Wild](https://huggingface.co/datasets/uqtwei2/PlantWild)
# 3. [PlantDoc-Dataset](https://github.com/pratikkayal/PlantDoc-Dataset?utm_source=chatgpt.com)
# 4. [Plant Village CC0: Public Domain](https://www.kaggle.com/datasets/moazeldsokyx/plantvillage)
# 5. [Multiple Plant Disease](https://www.kaggle.com/datasets/samareshkumar/multipleplantdiseases)
# 6. [Comprehensive Plant Disease Dataset](https://www.kaggle.com/Datasets/Itselif/Comprehensive-Plant-Disease-Dataset)
# 7. [Web sourced dataset for plant disease detection](https://zenodo.org/records/14051480)
# 8. [Crop pest and disease detection](https://www.kaggle.com/datasets/nirmalsankalana/crop-pest-and-disease-detection)
# 9. [20k multi class crop disease images](https://www.kaggle.com/datasets/jawadali1045/20k-multi-class-crop-disease-images)
# 10. [Top agriculture crop disease](https://www.kaggle.com/datasets/kamal01/top-agriculture-crop-disease)
# 11. [Plant Disease Detection with Supplement Name](https://github.com/manthan89-py/Plant-Disease-Detection/blob/main/Flask%20Deployed%20App/supplement_info.csv)
# 12. [Multimodal Plant Disease Dataset](https://github.com/shubham10divakar/Multimodal-Plant-Disease-Dataset)
# 13. [Multimodal plant disease dataset by subham-divakar](https://www.kaggle.com/datasets/shubhamdivakar/multimodal-plant-disease-dataset-by-subham-divakar)
# 14. [Plant disease classification](https://www.kaggle.com/datasets/turakut/plant-disease-classification)
# 15. [Plant disease processed](https://www.kaggle.com/datasets/harisri2005/plant-disease-processed)
# 16. [Crop diseases classification](kaggle.com/datasets/mexwell/crop-diseases-classification)
# 17. [Tomato-diseases-dataset-csvimages](https://www.kaggle.com/datasets/ammarnassanalhajali/tomato-diseases-dataset-csvimages)

# %% [markdown]
# ### Q2. For each dataset, identify at least one variable that would serve as the expected output of the final application.

# %% [markdown]
# 1. Plant Village CC BY-NC-SA 4.0 - Plant Disease Name
# 2. Plant Wild - Plant Disease Name
# 3. PlantDoc-Dataset - Plant Disease Name
# 4. Plant Village CC0: Public Domain - Plant Disease Name
# 5. Multiple Plant Disease - Plant Disease Name
# 6. Comprehensive Plant Disease Dataset - Plant Disease Name
# 7. Web sourced dataset for plant disease detection - Plant Disease Name
# 8. crop pest and disease detection - Plant Disease Name
# 9. 20k multi class crop disease images - Plant Disease Name
# 10. top agriculture crop disease - Plant Disease Name
# 11. Plant Disease Detection with Supplement Name - Plant Disease Name and Supplement
# 12. Multimodal Plant Disease Dataset - Plant Disease Name
# 13. Multimodal plant disease dataset by subham-divakar - Plant Disease Name
# 14. Plant disease classification - Plant Disease Name
# 15. Plant disease processed - Plant Disease Name
# 16. Crop diseases classification - Plant Disease Name
# 17. **Tomato diseases dataset csv images - Plant Disease Label text**

# %% [markdown]
# ## Selected Dataset

# %% [markdown]
# 1. Tomato Diseases Dataset CSV Images - Plant Disease Label text

# %% [markdown]
# ### Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ### Q3. Select the most appropriate dataset and carry out some data exploration by answering these questions in a Colab Notebook. Each question/response should appear on its own cell.

# %% [markdown]
# #### a. Select the most appropriate dataset and carry out some data exploration by answering these questions in a Colab Notebook. Each question/response should appear on its own cell.

# %%
df = pd.read_csv("Dataset.csv")

rows, columns = df.shape

print("Number of rows:", rows)
print("Number of columns:", columns)
# Out:
# Number of rows: 18160
# Number of columns: 5

# %% [markdown]
# #### b. What datatypes are contained in the dataset?

# %%
print(df.dtypes)
# Out:
# Unnamed: 0     int64
# path          object
# img           object
# label_text    object
# label          int64
# dtype: object

# %% [markdown]
# #### c. Is the dataset complete? i.e. no missing values?

# %%
# Counts the number of null values per column
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# Unnamed: 0    0
# path          0
# img           0
# label_text    0
# label         0
# dtype: int64

# %% [markdown]
# The dataset is complete and has no null values

# %% [markdown]
# #### d. Slice out the first 15 rows and last 20 rows and merge them into a new dataframe titled “df_sample”. Display this new dataframe.

# %%
# Retrieve the first 15 and last 20 records 
df_first_15 = df.head(15)
df_last_20 = df.tail(20)

# Use the concat function to join the dataframes
df_sample = pd.concat([df_first_15, df_last_20])

# Display the combined dataframe
print(df_sample)
# Out:
#        Unnamed: 0                                               path  \
# 0               0  ../input/plantvillage-dataset/color/Tomato___L...
# 1               1  ../input/plantvillage-dataset/color/Tomato___L...
# 2               2  ../input/plantvillage-dataset/color/Tomato___L...
# 3               3  ../input/plantvillage-dataset/color/Tomato___L...
# 4               4  ../input/plantvillage-dataset/color/Tomato___L...
# 5               5  ../input/plantvillage-dataset/color/Tomato___L...
# 6               6  ../input/plantvillage-dataset/color/Tomato___L...
# 7               7  ../input/plantvillage-dataset/color/Tomato___L...
# 8               8  ../input/plantvillage-dataset/color/Tomato___L...
# 9               9  ../input/plantvillage-dataset/color/Tomato___L...
# 10             10  ../input/plantvillage-dataset/color/Tomato___L...
# 11             11  ../input/plantvillage-dataset/color/Tomato___L...
# 12             12  ../input/plantvillage-dataset/color/Tomato___L...
# ...
